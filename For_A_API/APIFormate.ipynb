# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df
# Out:
#         id                                          title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5      129                                  Spirited Away
# 6    19404                    Dilwale Dulhania Le Jayenge
# 7      155                                The Dark Knight
# 8      497                                 The Green Mile
# 9   496243                                       Parasite
# 10     680                                   Pulp Fiction
# 11  372058                                     Your Name.
# 12     122  The Lord of the Rings: The Return of the King
# 13      13                                   Forrest Gump
# 14     429                 The Good, the Bad and the Ugly
# 15     769                                     GoodFellas
# 16     346                                  Seven Samurai
# 17  157336                                   Interstellar
# 18   12477                         Grave of the Fireflies
# 19     637                              Life Is Beautiful
#
#                                              overview release_date  \
# 0   Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1   Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2   In the continuing saga of the Corleone crime f...   1974-12-20
# 3   The true story of how businessman Oskar Schind...   1993-12-15
# 4   The defense and the prosecution have rested an...   1957-04-10
# 5   A young girl, Chihiro, becomes trapped in a st...   2001-07-20
# 6   Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 7   Batman raises the stakes in his war on crime. ...   2008-07-16
# 8   A supernatural tale set on death row in a Sout...   1999-12-10
# 9   All unemployed, Ki-taek's family takes peculia...   2019-05-30
# 10  A burger-loving hit man, his philosophical par...   1994-09-10
# 11  High schoolers Mitsuha and Taki are complete s...   2016-08-26
# 12  As armies mass for a final battle that will de...   2003-12-17
# 13  A man with a low IQ has accomplished great thi...   1994-06-23
# 14  While the Civil War rages on between the Union...   1966-12-22
# 15  The true story of Henry Hill, a half-Irish, ha...   1990-09-12
# 16  A samurai answers a village's request for prot...   1954-04-26
# 17  The adventures of a group of explorers who mak...   2014-11-05
# 18  In the final months of World War II, 14-year-o...   1988-04-16
# 19  A touching story of an Italian book seller of ...   1997-12-20
#
#     popularity  vote_average  vote_count
# 0      186.793         8.708       27680
# 1      206.671         8.689       20995
# 2      118.395         8.600       12668
# 3      105.356         8.567       16124
# 4       61.535         8.547        8856
# 5      142.673         8.500       16794
# 6       29.938         8.500        4458
# 7      170.603         8.500       33374
# 8      110.559         8.507       17770
# 9      114.901         8.502       18621
# 10     140.978         8.500       28288
# 11      83.715         8.487       11570
# 12     169.435         8.500       24621
# 13      96.359         8.500       27812
# 14      82.839         8.500        8791
# 15      62.039         8.457       13089
# 16      34.335         8.500        3784
# 17     342.204         8.451       36430
# 18       0.066         8.500        5700
# 19      54.671         8.400       13180

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 8555    9932              Analyze That
# 8556  492621          The Midnight Man
# 8557   70706           Very Good Girls
# 8558   35626  Return to Sleepaway Camp
# 8559   27726                         Q
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# 8555  The mafia's Paul Vitti is back in prison and w...   2002-12-06
# 8556  A girl and her friends find a game in the atti...   2016-09-30
# 8557  Two New York City girls make a pact to lose th...   2013-01-22
# 8558  It's summer camp as usual at Camp Manabe where...   2008-11-04
# 8559  New York police are bemused by reports of a gi...   1982-09-08
#
#       popularity  vote_average  vote_count
# 0        186.793         8.708       27680
# 1        206.671         8.689       20995
# 2        118.395         8.600       12668
# 3        105.356         8.567       16124
# 4         61.535         8.547        8856
# ...          ...           ...         ...
# 8555      10.072         5.815        1249
# 8556       8.192         5.814         416
# 8557       8.310         5.814         432
# 8558       8.633         5.800         318
# 8559       7.140         5.800         452
#
# [8560 rows x 7 columns]

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')

# %% [markdown]
# [api web link](https://rapidapi.com/hub)
